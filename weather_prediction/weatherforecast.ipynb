# %%
import pandas as pd
weather = pd.read_csv("weather.csv" , index_col="DATE") # use pd to read weather file

# %%
weather # display weather data
# Out:
#                 STATION                              NAME  ACMH   ACSH   AWND  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0   90.0    NaN
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   20.0    NaN
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0  100.0    NaN
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  10.0   20.0    NaN
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   10.0    NaN
# ...                 ...                               ...   ...    ...    ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN   9.62
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  12.08
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  14.99
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  16.78
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN    NaN
#
# ...

# %%
null_dt = weather.apply(pd.isnull).sum()/weather.shape[0] # percentage of null values

# %%
null_dt # display data percentages of null values
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.501478
# ACSH       0.501426
# AWND       0.265256
# FMTM       0.475087
# PGTM       0.363872
# PRCP       0.000000
# SNOW       0.000000
# SNWD       0.000104
# TAVG       0.680406
# TMAX       0.000000
# TMIN       0.000000
# TSUN       0.998393
# WDF1       0.501685
# WDF2       0.498678
# WDF5       0.502981
# WDFG       0.734484
# WDFM       0.999948
# WESD       0.685228
# WSF1       0.501530
# WSF2       0.498678
# WSF5       0.503033
# WSFG       0.613055
# WSFM       0.999948
# WT01       0.630217
# WT02       0.935034
# WT03       0.933271
# WT04       0.982579
# WT05       0.981127
# WT06       0.990615
# WT07       0.994400
# WT08       0.796962
# WT09       0.992741
# WT11       0.999274
# WT13       0.886711
# WT14       0.954010
# WT15       0.997822
# WT16       0.658993
# WT17       0.996889
# WT18       0.939493
# WT21       0.999741
# WT22       0.997459
# WV01       0.999948
# dtype: float64

# %%
valid_columns = weather.columns[null_dt < .05] # data which has null value of less than < .05

# %%
valid_columns # display columns which less missing values
# Out:
# Index(['STATION', 'NAME', 'PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN'], dtype='object')

# %%
weather = weather[valid_columns].copy() # put those valid columns to our weather data and use those only

# %%
weather = weather.ffill() # use to fill missing values with the last observed non-null value

# %%
weather.apply(pd.isnull).sum() # check columns values with null value
# Out:
# STATION    0
# NAME       0
# PRCP       0
# SNOW       0
# SNWD       0
# TMAX       0
# TMIN       0
# dtype: int64

# %%
weather.dtypes # check our datatypes are appropriate
# Out:
# STATION     object
# NAME        object
# PRCP       float64
# SNOW       float64
# SNWD       float64
# TMAX         int64
# TMIN         int64
# dtype: object

# %%
weather.index # make sure the row label are right
# Out:
# Index(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04', '1970-01-05',
#        '1970-01-06', '1970-01-07', '1970-01-08', '1970-01-09', '1970-01-10',
#        ...
#        '2022-10-12', '2022-10-13', '2022-10-14', '2022-10-15', '2022-10-16',
#        '2022-10-17', '2022-10-18', '2022-10-19', '2022-10-20', '2022-10-21'],
#       dtype='object', name='DATE', length=19287)

# %%
weather.index = pd.to_datetime(weather.index) # convert the object dtype to a date time

# %%
weather.index # check our data is in a date-time format
# Out:
# DatetimeIndex(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04',
#                '1970-01-05', '1970-01-06', '1970-01-07', '1970-01-08',
#                '1970-01-09', '1970-01-10',
#                ...
#                '2022-10-12', '2022-10-13', '2022-10-14', '2022-10-15',
#                '2022-10-16', '2022-10-17', '2022-10-18', '2022-10-19',
#                '2022-10-20', '2022-10-21'],
#               dtype='datetime64[ns]', name='DATE', length=19287, freq=None)

# %%
weather.index.year.value_counts().sort_index() # to check gaps in our data we count and sort it out and check it
# Out:
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1981    365
# 1982    365
# 1983    365
# 1984    366
# 1985    365
# 1986    365
# 1987    365
# 1988    366
# 1989    365
# 1990    365
# 1991    365
# 1992    366
# 1993    365
# 1994    365
# 1995    365
# 1996    366
# 1997    365
# 1998    365
# 1999    365
# 2000    366
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    294
# Name: DATE, dtype: int64

# %%
weather["SNWD"].plot() # show snow depth by plot bar

# %%
weather
# Out:
#                 STATION                              NAME  PRCP  SNOW  SNWD  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             TMAX  TMIN
# DATE
# ...

# %%
weather["target"] = weather.shift(-1)["TMAX"] # predicts tommorrow tmax value

# %%
weather
# Out:
#                 STATION                              NAME  PRCP  SNOW  SNWD  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             TMAX  TMIN  target
# DATE
# ...

# %%
weather = weather.ffill() # we used to fill the last label with the null value of the previous

# %%
weather
# Out:
#                 STATION                              NAME  PRCP  SNOW  SNWD  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             TMAX  TMIN  target
# DATE
# ...

# %%
from sklearn.linear_model import Ridge # uses for find correlation and prevent overffiting

# %%
weather.corr() # finds correlation between our datasets
# Out:
#             PRCP      SNOW      SNWD      TMAX      TMIN    target
# PRCP    1.000000  0.151051  0.001178 -0.007210  0.052279 -0.003358
# SNOW    0.151051  1.000000  0.232567 -0.175075 -0.159285 -0.172737
# SNWD    0.001178  0.232567  1.000000 -0.259858 -0.256977 -0.241054
# TMAX   -0.007210 -0.175075 -0.259858  1.000000  0.955487  0.915296
# TMIN    0.052279 -0.159285 -0.256977  0.955487  1.000000  0.915461
# target -0.003358 -0.172737 -0.241054  0.915296  0.915461  1.000000

# %%
rr = Ridge(alpha=1.0) # initialize the ridge regression modele

# %%
predictors = weather.columns[~weather.columns.isin(["target" , "NAME" ,"STATION"])] 
# take all except those to create columns to predictors

# %%
predictors # list our list of predictors
# Out:
# Index(['PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN'], dtype='object')

# %%
def backtest(weather, model, predictors, start=3650, step=90):
    all_prediction = []
    
    for i in range(start, weather.shape[0], step):
        train = weather.iloc[:i,:]
        test = weather.iloc[i:(i+step),:]
        
        model.fit(train[predictors], train["target"])
        preds = model.predict(test[predictors])
        
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"], preds], axis=1)
        
        combined.columns = ["actual" , "prediction"]
        combined["diff"] =(combined["prediction"] - combined["actual"]).abs()
        
        all_prediction.append(combined)
    return pd.concat(all_prediction)

# %%
predictions = backtest(weather, rr, predictors)

# %%
predictions
# Out:
#             actual  prediction       diff
# DATE
# 1979-12-30    43.0   50.228677   7.228677
# 1979-12-31    42.0   43.673360   1.673360
# 1980-01-01    41.0   41.578838   0.578838
# 1980-01-02    36.0   43.961225   7.961225
# 1980-01-03    30.0   40.203976  10.203976
# ...            ...         ...        ...
# 2022-10-17    58.0   67.543378   9.543378
# 2022-10-18    56.0   60.511676   4.511676
# 2022-10-19    61.0   57.030365   3.969635
# 2022-10-20    64.0   59.784761   4.215239
# 2022-10-21    64.0   60.609728   3.390272
#
# [15637 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 5.139314592169849

# %%
def pct_diff(old, new):
    return(new - old)/old
def compute_rolling(weather, horizon, col):
    label = f"rolling_{horizon}_{col}"
    
    weather[label] = weather[col].rolling(horizon).mean()
    weather[f"{label}_pct"] = pct_diff(weather[label], weather[col])
    return weather
rolling_horizons = [3,14]

for horizon in rolling_horizons:
    for col in ["TMAX" ,"TMIN", "PRCP"]:
        weather = compute_rolling(weather,horizon, col)

# %%
weather
# Out:
#                 STATION                              NAME  PRCP  SNOW  SNWD  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
# ...

# %%
weather = weather.iloc[14:,:]

# %%
weather
# Out:
#                 STATION                              NAME  PRCP  SNOW  SNWD  \
# DATE
# 1970-01-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-16  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.10   0.0   0.0
# 1970-01-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
# ...

# %%
weather = weather.fillna(0)

# %%
def expand_mean(df):
    return df.expanding(1).mean()

for col in ["TMAX", "TMIN", "PRCP"]:
    weather[f"month_avg_{col}"] = weather[col].groupby(weather.index.month, group_keys=False).apply(expand_mean)
    weather[f"day_avg_{col}"] = weather[col].groupby(weather.index.dayofyear, group_keys=False).apply(expand_mean)

# %%
weather
# Out:
#                 STATION                              NAME  PRCP  SNOW  SNWD  \
# DATE
# 1970-01-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-16  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.10   0.0   0.0
# 1970-01-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
# ...

# %%
predictors = weather.columns[~weather.columns.isin(["target" , "NAME" ,"STATION"])]

# %%
predictors
# Out:
# Index(['PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN', 'rolling_3_TMAX',
#        'rolling_3_TMAX_pct', 'rolling_3_TMIN', 'rolling_3_TMIN_pct',
#        'rolling_3_PRCP', 'rolling_3_PRCP_pct', 'rolling_14_TMAX',
#        'rolling_14_TMAX_pct', 'rolling_14_TMIN', 'rolling_14_TMIN_pct',
#        'rolling_14_PRCP', 'rolling_14_PRCP_pct', 'month_avg_TMAX',
#        'day_avg_TMAX', 'month_avg_TMIN', 'day_avg_TMIN', 'month_avg_PRCP',
#        'day_avg_PRCP'],
#       dtype='object')

# %%
predictions = backtest(weather, rr, predictors)

# %%
mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 4.787535578056654

# %%
predictions.sort_values("diff", ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 1990-03-12    85.0   54.439356  30.560644
# 2007-03-26    78.0   50.006909  27.993091
# 1998-03-26    80.0   52.209538  27.790462
# 2003-04-15    86.0   59.705202  26.294798
# 1997-02-26    71.0   45.132035  25.867965
# ...            ...         ...        ...
# 1982-08-01    84.0   84.002370   0.002370
# 2014-08-25    82.0   81.998228   0.001772
# 2014-12-11    41.0   40.998283   0.001717
# 2011-08-22    80.0   79.999229   0.000771
# 2006-07-25    83.0   82.999397   0.000603
#
# [15623 rows x 3 columns]

# %%
predictions["diff"].round().value_counts().sort_index().plot()
